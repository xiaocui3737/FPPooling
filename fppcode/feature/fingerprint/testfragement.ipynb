# %%
from fragment import FragmentFP, fragKeys
from rdkit import Chem
from utils import showAtomIdx, highlight

# %%
smiles = 'O=C(NCC1CCCCC1)[C@@H](Cc1cc2cc(ccc2nc1N)-c1ccccc1C)CCC'

mol = Chem.MolFromSmiles(smiles)
showAtomIdx(mol)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
fp = FragmentFP()
print(fp.nBits)
fp = fp(mol)
fp.bitinfodict.keys()
# Out:
# 86
# dict_keys([0, 1, 16, 17, 18, 19, 21, 32, 58, 67, 68, 79, 84])

# %%
bitidx = 67
fp.bits[bitidx].info
# Out:
# ((14, 19),)

# %%
fp.bits[bitidx].show(mol)
